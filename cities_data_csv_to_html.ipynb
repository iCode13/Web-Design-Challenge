# %%
# Dependencies and setup
import pandas as pd

# Read CSV file into a dataframe
cities_df = pd.read_csv("Resources/cities.csv")
cities_df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
cities_df = cities_df.drop(columns=['City_ID'])
cities_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    jacareacanga           0      BR  1528902000        62  -6.22  -57.76
# 1      kaitangata         100      NZ  1528905304        94 -46.28  169.85
# 2        goulburn          20      AU  1528905078        91 -34.75  149.72
# 3            lata          76      IN  1528905305        89  30.78   78.62
# 4      chokurdakh           0      RU  1528905306        88  70.62  147.90
# ..            ...         ...     ...         ...       ...    ...     ...
# 542        scalea          36      IT  1528905631       100  39.82   15.79
# 543    san andres          68      PH  1528905632       100  13.32  122.68
# 544        muisne          92      EC  1528905633        84   0.61  -80.02
# 545           ati          20      TD  1528905633        25  13.21   18.34
# 546      san luis           0      AR  1528905472        53 -33.30  -66.34
#
#      Max Temp  Wind Speed
# 0       89.60        6.93
# ...

# %%
# Export dataframe as HTML
cities_df.to_html("../Web-Visualizations/cities_data.html")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-ac98363e73b8> in <module>
#       1 # Export dataframe as HTML
# ----> 2 cities_df.to_html("../Web-Visualizations/cities_data.html")
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, bold_rows, classes, escape, notebook, border, table_id, render_links, encoding)
#    2472             notebook=notebook,
#    2473             border=border,
# -> 2474             encoding=encoding,
#    2475         )
#    2476
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     987         Klass = NotebookFormatter if notebook else HTMLFormatter
# ...
